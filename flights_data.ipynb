# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
table = []
flights = ['6E171','6E5335','6E993','6E167','6E179','6E181','6E5339','6E223','6E957','6E189','6E755','6E191','6E129','6E843','6E197','6E185','6E665','6E155','I5314','I5716','I5332','I5482','AI349','AI887','AI665','AI678','AI865','AI315','AI317','AI636','AI102','AI441','AI24','AI624','AI805','AI191','AI863','G82501','G8338','G8530','G8334','G8336','G8640','G8446','G8429','G8544','SG8287','SG8153','SG8701','SG8723','SG8911','SG8161','SG8709','SG8169','SG8715','SG8159','UK975','UK923','UK943','UK963','UK927','UK995','UK945','UK993','UK941','UK955','UK977','UK985','UK953','UK981','UK967','6E2625','6E2135','6E2562','6E2132','6E2228','6E5032','6E5022','6E2032','6E2988','6E2783','6E2808','6E2716','6E2305','6E2289','6E2484','I52878','I5737','I5741','I5722','AI804','AI505','AI501','AI503','AI87','AI173','AI802','G8116','G8117','G8120','G8118','SG8906','SG136','SG192','SG198','SG8720','UK110','UK812','UK816','UK820','UK814','UK818','6E456','6E5322','6E5324','6E424','6E734','6E346','6E414','6E361','6E5331','6E6449','6E5348','6E6794','6E849','I5303','I5304','I5306','I5334','AI640','AI604','AI507','AI608','AI610','G8418','G8395','G8320','G8526','SG456','SG438','SG6351','UK858','UK846','UK852','UK864','UK854','UK850','UK866']
for mm in range(11,13):
    for dd in range(1,32):
        for flight in flights: 
            url = "https://airportinfo.live/flight/"+flight+"?d=2019-"+str(mm)+"-"+str(dd)
            req = requests.get(url)
            webp = req.text
            soup = BeautifulSoup(webp, 'html.parser')
            airline =(soup.find("span", "bold flightAirline")).text
            flight_number =(soup.find("span", "flightNumber")).text
            #duration =(soup.find("span", "duration bold ")).text
            distance =(soup.find("span", "duration_distance")).text
            distance = distance.split()[3] 
            from_city =(soup.find("span", "bold from_city")).text
            to_city =(soup.find("span", "bold to_city")).text
            times = soup.findAll("div","important_time")
            times_text = [t.text for t in times]
            date = url[-10:]
            new_date = date.split('-')
            year = new_date[0][-4:]
            month = new_date[1]
            day = new_date[2]
            row = []
            row.append(airline)
            row.append(flight_number)
            row.append(from_city)
            row.append(to_city)
            row.append(distance)
            #row.append(duration)
            row.append(day)
            row.append(month)
            row.append(year)
            row = row + times_text
            table.append(row)

# %%
    for dd in range(1,32):
        url = "https://airportinfo.live/flight/"+flight+"?d=2020-1"+"-"+str(dd)
        req = requests.get(url)
        webp = req.text
        soup = BeautifulSoup(webp, 'html.parser')
        airline =(soup.find("span", "bold flightAirline")).text
        flight_number =(soup.find("span", "flightNumber")).text
        #duration =(soup.find("span", "duration bold ")).text
        distance =(soup.find("span", "duration_distance")).text
        distance = distance.split()[3] 
        from_city =(soup.find("span", "bold from_city")).text
        to_city =(soup.find("span", "bold to_city")).text
        times = soup.findAll("div","important_time")
        times_text = [t.text for t in times]
        date = url[-10:]
        new_date = date.split('-')
        year = new_date[0][-4:]
        month = new_date[1]
        day = new_date[2]
        row = []
        row.append(airline)
        row.append(flight_number)
        row.append(from_city)
        row.append(to_city)
        row.append(distance)
        #row.append(duration)
        row.append(day)
        row.append(month)
        row.append(year)
        row = row + times_text
        table.append(row)

# %%
tab_arr = np.array(table)

# %%
data = pd.DataFrame(tab_arr, columns = ['Airline','Flight Number','Origin Airport','Destination Airport','Distance(Km)','DD','MM','YY','Scheduled Departure','Scheduled Arrival','Actual Departure','Actual Arrival'])

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
import requests

# %%
import bs4

# %%
url = "https://weather.com/weather/monthly/l/32355ced66b7ce3ab7ccafb0a4f45f12e7c915bcf8454f712efa57474ba8d6c8"
req = requests.get(url)
webp = req.text
soup = BeautifulSoup(webp, 'html.parser')
print(soup.prettify().encode('UTF-8'))
# Out:
# b'<!DOCTYPE doctype html>\n<html data-connection-speed="4g" data-device-class="desktop" dir="ltr" itemscope="" itemtype="http://schema.org/Organization" lang="en-US" prefix="fb: http://ogp.me/ns/fb# og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product#">\n <head itemscope="" itemtype="http://schema.org/WebSite">\n  <meta charset="utf-8"/>\n  <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0, viewport-fit=cover" name="viewport"/>\n  <script charset="UTF-8">\n   window.loadNewRelic=false;(function(){var rNumber=Math.random();if(rNumber>=0.95){window.loadNewRelic=true;}if(window.loadNewRelic){window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var o=e[n]={exports:{}};t[n][0].call(o.exports,function(e){var o=t[n][1][e];return r(o||e)},o,o.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var o=0;o<n.length;o++)r(n[o]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var o,i=t("ee"),a=t(20),c={};try{o=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,o.indexOf("dev")!==-1&&(c.dev=!0),o.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&i.on("internal-error",function(t){r(t.stack)}),c.dev&&i.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,o){try{d?d-=1:i("err",[o||new UncaughtException(t,e,n)])}catch(c){try{i("ierr",[c,s.now(),!0])}catch(u){}}return"function"==typeof f&&f.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function o(t){i("err",[t,s.now()])}var i=t("handle"),a=t(21),c=t("ee"),s=t("loader"),f=window.onerror,u=!1,d=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(p){"stack"in p&&(t(13),t(12),"addEventListener"in window&&t(6),s.xhrWrappable&&t(14),u=!0)}c.on("fn-start",function(t,e,n){u&&(d+=1)}),c.on("fn-err",function(t,e,n){u&&(this.thrown=!0,o(n))}),c.on("fn-end",function(){u&&!this.thrown&&d>0&&(d-=1)}),c.on("internal-error",function(t){i("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(){M++,S=y.hash,this[u]=b.now()}function o(){M--,y.hash!==S&&i(0,!0);var t=b.now();this[l]=~~this[l]+t-this[u],this[d]=t}function i(t,e){E.emit("newURL",[""+y,e])}function a(t,e){t.on(e,function(){this[e]=b.now()})}var c="-start",s="-end",f="-body",u="fn"+c,d="fn"+s,p="cb"+c,h="cb"+s,l="jsTime",m="fetch",v="addEventListener",w=window,y=w.location,b=t("loader");if(w[v]&&b.xhrWrappable){var g=t(10),x=t(11),E=t(8),P=t(6),O=t(13),R=t(7),T=t(14),L=t(9),j=t("ee"),N=j.get("tracer");t(15),b.features.spa=!0;var S,M=0;j.on(u,r),j.on(p,r),j.on(d,o),j.on(h,o),j.buffer([u,d,"xhr-done","xhr-resolved"]),P.buffer([u]),O.buffer(["setTimeout"+s,"clearTimeout"+c,u]),T.buffer([u,"new-xhr","send-xhr"+c]),R.buffer([m+c,m+"-done",m+f+c,m+f+s]),E.buffer(["newURL"]),g.buffer([u]),x.buffer(["propagate",p,h,"executor-err","resolve"+c]),N.buffer([u,"no-"+u]),L.buffer(["new-jsonp","cb-start","jsonp-error","jsonp-end"]),a(T,"send-xhr"+c),a(j,"xhr-resolved"),a(j,"xhr-done"),a(R,m+c),a(R,m+"-done"),a(L,"new-jsonp"),a(L,"jsonp-end"),a(L,"cb-start"),E.on("pushState-end",i),E.on("replaceState-end",i),w[v]("hashchange",i,!0),w[v]("load",i,!0),w[v]("popstate",function(){i(0,M>1)},!0)}},{}],5:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var o=t("ee"),i=t("handle"),a=t(13),c=t(12),s="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",p="resource",h="-start",l="-end",m="fn"+h,v="fn"+l,w="bstTimer",y="pushState",b=t("loader");b.features.st ...

# %%
import pandas as pd
set6=pd.read_csv('set6.csv')
btom=pd.read_csv('bangalore_to_mumbai_3_mnths.csv')
#set7=set6.append(btom)
set7 = pd.concat([set6,btom])
# Out:
# C:\Users\Shridam\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """

# %%
set7
# Out:
#      Actual Arrival Actual Departure Airline  DD Destination Airport  \
# 0              7:05             4:55      6E   1              Mumbai
# 1              8:16             6:28      6E   1              Mumbai
# 2              8:45             6:47      6E   1              Mumbai
# 3              9:21             7:35      6E   1              Mumbai
# 4             10:35             8:45      6E   1                 Goa
# ...             ...              ...     ...  ..                 ...
# 3343          11:37             9:35      UK  31              Mumbai
# 3344          13:12            11:25      UK  31              Mumbai
# 3345          20:15            18:30      UK  31              Mumbai
# 3346          21:52            19:52      UK  31              Mumbai
# 3347          22:55            21:30      UK  31              Mumbai
#
#       Distance(Km) Duration  Flight Number  MM Origin Airport  \
# 0             1139    02:10            171  11      New Delhi
# 1             1139    01:48           5335  11      New Delhi
# 2             1139    01:58            993  11      New Delhi
# 3             1139    01:46            167  11      New Delhi
# 4              412    01:50            179  11         Mumbai
# ...            ...      ...            ...  ..            ...
# 3343           848      NaN            852  12      Bangalore
# 3344           848      NaN            864  12      Bangalore
# 3345           848      NaN            854  12      Bangalore
# 3346           848      NaN            850  12      Bangalore
# 3347           848      NaN            866  12      Bangalore
#
#      Scheduled Arrival Scheduled Departure  Unnamed: 0    YY
# 0                 7:05                4:55           0  2019
# 1                 7:45                5:35           1  2019
# 2                 8:40                6:30           2  2019
# 3                 9:40                7:35           3  2019
# 4                10:40                8:25           4  2019
# ...                ...                 ...         ...   ...
# 3343             11:20                9:40        3343  2019
# 3344             13:20               11:30        3344  2019
# 3345             20:15               18:30        3345  2019
# 3346             21:50               19:55        3346  2019
# 3347             23:25               21:30        3347  2019
#
# [25110 rows x 14 columns]

# %%
set7 = set7.reset_index().drop(['index','Unnamed: 0'], axis = 1)

# %%
set7
# Out:
#       Actual Arrival Actual Departure Airline  DD Destination Airport  \
# 0               7:05             4:55      6E   1              Mumbai
# 1               8:16             6:28      6E   1              Mumbai
# 2               8:45             6:47      6E   1              Mumbai
# 3               9:21             7:35      6E   1              Mumbai
# 4              10:35             8:45      6E   1                 Goa
# ...              ...              ...     ...  ..                 ...
# 25105          11:37             9:35      UK  31              Mumbai
# 25106          13:12            11:25      UK  31              Mumbai
# 25107          20:15            18:30      UK  31              Mumbai
# 25108          21:52            19:52      UK  31              Mumbai
# 25109          22:55            21:30      UK  31              Mumbai
#
#        Distance(Km) Duration  Flight Number  MM Origin Airport  \
# 0              1139    02:10            171  11      New Delhi
# 1              1139    01:48           5335  11      New Delhi
# 2              1139    01:58            993  11      New Delhi
# 3              1139    01:46            167  11      New Delhi
# 4               412    01:50            179  11         Mumbai
# ...             ...      ...            ...  ..            ...
# 25105           848      NaN            852  12      Bangalore
# 25106           848      NaN            864  12      Bangalore
# 25107           848      NaN            854  12      Bangalore
# 25108           848      NaN            850  12      Bangalore
# 25109           848      NaN            866  12      Bangalore
#
#       Scheduled Arrival Scheduled Departure    YY
# 0                  7:05                4:55  2019
# 1                  7:45                5:35  2019
# 2                  8:40                6:30  2019
# 3                  9:40                7:35  2019
# 4                 10:40                8:25  2019
# ...                 ...                 ...   ...
# 25105             11:20                9:40  2019
# 25106             13:20               11:30  2019
# 25107             20:15               18:30  2019
# 25108             21:50               19:55  2019
# 25109             23:25               21:30  2019
#
# [25110 rows x 13 columns]

# %%
import pandas as pd
#set7=pd.read_csv('set7.csv')
mtob=pd.read_csv('mumbai_to_bangalore_3_mnths.csv')
#set7=set6.append(btom)
set8 = pd.concat([set7,mtob])
set8
# Out:
# C:\Users\Shridam\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """
#      Actual Arrival Actual Departure Airline  DD Destination Airport  \
# 0              7:05             4:55      6E   1              Mumbai
# 1              8:16             6:28      6E   1              Mumbai
# 2              8:45             6:47      6E   1              Mumbai
# 3              9:21             7:35      6E   1              Mumbai
# 4             10:35             8:45      6E   1                 Goa
# ...             ...              ...     ...  ..                 ...
# 3343          22:54            21:06      UK  31           Bangalore
# 3344           7:41             6:11      AI  31           Bangalore
# 3345          11:17             9:30      AI  31           Bangalore
# 3346          19:47            18:03      AI  31           Bangalore
# 3347          21:45            20:05      AI  31           Bangalore
#
#       Distance(Km) Duration  Flight Number  MM Origin Airport  \
# 0             1139    02:10            171  11      New Delhi
# 1             1139    01:48           5335  11      New Delhi
# 2             1139    01:58            993  11      New Delhi
# 3             1139    01:46            167  11      New Delhi
# 4              412    01:50            179  11         Mumbai
# ...            ...      ...            ...  ..            ...
# 3343           848      NaN            857  12         Mumbai
# 3344           848      NaN            603  12         Mumbai
# 3345           848      NaN            639  12         Mumbai
# 3346           848      NaN            607  12         Mumbai
# 3347           848      NaN            609  12         Mumbai
#
#      Scheduled Arrival Scheduled Departure  Unnamed: 0    YY
# 0                 7:05                4:55         NaN  2019
# 1                 7:45                5:35         NaN  2019
# 2                 8:40                6:30         NaN  2019
# 3                 9:40                7:35         NaN  2019
# 4                10:40                8:25         NaN  2019
# ...                ...                 ...         ...   ...
# 3343             22:50               21:05      3343.0  2019
# 3344              7:55                6:15      3344.0  2019
# 3345             11:10                9:15      3345.0  2019
# 3346             18:30               16:40      3346.0  2019
# 3347             21:45               20:05      3347.0  2019
#
# [28458 rows x 14 columns]

# %%
set8 = set8.reset_index().drop(['index','Unnamed: 0'], axis = 1)

# %%
set8
# Out:
#       Actual Arrival Actual Departure Airline  DD Destination Airport  \
# 0               7:05             4:55      6E   1              Mumbai
# 1               8:16             6:28      6E   1              Mumbai
# 2               8:45             6:47      6E   1              Mumbai
# 3               9:21             7:35      6E   1              Mumbai
# 4              10:35             8:45      6E   1                 Goa
# ...              ...              ...     ...  ..                 ...
# 28453          22:54            21:06      UK  31           Bangalore
# 28454           7:41             6:11      AI  31           Bangalore
# 28455          11:17             9:30      AI  31           Bangalore
# 28456          19:47            18:03      AI  31           Bangalore
# 28457          21:45            20:05      AI  31           Bangalore
#
#        Distance(Km) Duration  Flight Number  MM Origin Airport  \
# 0              1139    02:10            171  11      New Delhi
# 1              1139    01:48           5335  11      New Delhi
# 2              1139    01:58            993  11      New Delhi
# 3              1139    01:46            167  11      New Delhi
# 4               412    01:50            179  11         Mumbai
# ...             ...      ...            ...  ..            ...
# 28453           848      NaN            857  12         Mumbai
# 28454           848      NaN            603  12         Mumbai
# 28455           848      NaN            639  12         Mumbai
# 28456           848      NaN            607  12         Mumbai
# 28457           848      NaN            609  12         Mumbai
#
#       Scheduled Arrival Scheduled Departure    YY
# 0                  7:05                4:55  2019
# 1                  7:45                5:35  2019
# 2                  8:40                6:30  2019
# 3                  9:40                7:35  2019
# 4                 10:40                8:25  2019
# ...                 ...                 ...   ...
# 28453             22:50               21:05  2019
# 28454              7:55                6:15  2019
# 28455             11:10                9:15  2019
# 28456             18:30               16:40  2019
# 28457             21:45               20:05  2019
#
# [28458 rows x 13 columns]

# %%
set8.columns.values
# Out:
# array(['Actual Arrival', 'Actual Departure', 'Airline', 'DD',
#        'Destination Airport', 'Distance(Km)', 'Duration', 'Flight Number',
#        'MM', 'Origin Airport', 'Scheduled Arrival', 'Scheduled Departure',
#        'YY'], dtype=object)

# %%
final_data = set8[['Actual Arrival', 'Actual Departure', 'Airline', 'DD','MM','YY',
       'Destination Airport', 'Distance(Km)', 'Duration', 'Flight Number'
        ,'Origin Airport', 'Scheduled Arrival', 'Scheduled Departure']]

# %%
final_data = set8[[ 'Airline','Flight Number','Origin Airport','Destination Airport','Distance(Km)','Duration','DD','MM','YY','Scheduled Arrival', 'Scheduled Departure','Actual Arrival','Actual Departure']]

# %%
final_data
# Out:
#       Airline  Flight Number Origin Airport Destination Airport  Distance(Km)  \
# 0          6E            171      New Delhi              Mumbai          1139
# 1          6E           5335      New Delhi              Mumbai          1139
# 2          6E            993      New Delhi              Mumbai          1139
# 3          6E            167      New Delhi              Mumbai          1139
# 4          6E            179         Mumbai                 Goa           412
# ...       ...            ...            ...                 ...           ...
# 28453      UK            857         Mumbai           Bangalore           848
# 28454      AI            603         Mumbai           Bangalore           848
# 28455      AI            639         Mumbai           Bangalore           848
# 28456      AI            607         Mumbai           Bangalore           848
# 28457      AI            609         Mumbai           Bangalore           848
#
#       Duration  DD  MM    YY Scheduled Arrival Scheduled Departure  \
# 0        02:10   1  11  2019              7:05                4:55
# 1        01:48   1  11  2019              7:45                5:35
# 2        01:58   1  11  2019              8:40                6:30
# 3        01:46   1  11  2019              9:40                7:35
# 4        01:50   1  11  2019             10:40                8:25
# ...        ...  ..  ..   ...               ...                 ...
# 28453      NaN  31  12  2019             22:50               21:05
# 28454      NaN  31  12  2019              7:55                6:15
# 28455      NaN  31  12  2019             11:10                9:15
# 28456      NaN  31  12  2019             18:30               16:40
# 28457      NaN  31  12  2019             21:45               20:05
#
#       Actual Arrival Actual Departure
# 0               7:05             4:55
# 1               8:16             6:28
# 2               8:45             6:47
# 3               9:21             7:35
# 4              10:35             8:45
# ...              ...              ...
# 28453          22:54            21:06
# 28454           7:41             6:11
# 28455          11:17             9:30
# 28456          19:47            18:03
# 28457          21:45            20:05
#
# [28458 rows x 13 columns]

# %%
final_data.to_csv('set7.csv',index=False,encoding='utf-8')

# %%
import pandas as pd
#set9=pd.read_csv('set7.csv')
dtob=pd.read_csv('delhi_to_bangalore_3_mnths.csv')
#set7=set6.append(btom)
set9 = pd.concat([final_data,dtob])
set9
# Out:
# C:\Users\Shridam\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """
#      Actual Arrival Actual Departure Airline  DD Destination Airport  \
# 0              7:05             4:55      6E   1              Mumbai
# 1              8:16             6:28      6E   1              Mumbai
# 2              8:45             6:47      6E   1              Mumbai
# 3              9:21             7:35      6E   1              Mumbai
# 4             10:35             8:45      6E   1                 Goa
# ...             ...              ...     ...  ..                 ...
# 4380          11:53             9:27      AI  31           Bangalore
# 4381          16:00            13:30      AI  31           Bangalore
# 4382          20:39            17:54      AI  31           Bangalore
# 4383          22:16            19:31      AI  31           Bangalore
# 4384          23:33            20:51      AI  31           Bangalore
#
#       Distance(Km) Duration  Flight Number  MM Origin Airport  \
# 0             1139    02:10            171  11      New Delhi
# 1             1139    01:48           5335  11      New Delhi
# 2             1139    01:58            993  11      New Delhi
# 3             1139    01:46            167  11      New Delhi
# 4              412    01:50            179  11         Mumbai
# ...            ...      ...            ...  ..            ...
# 4380          1736      NaN            506  12      New Delhi
# 4381          1736      NaN            502  12      New Delhi
# 4382          1736      NaN            174  12      New Delhi
# 4383          1736      NaN            801  12      New Delhi
# 4384          1736      NaN            504  12      New Delhi
#
#      Scheduled Arrival Scheduled Departure  Unnamed: 0    YY
# 0                 7:05                4:55         NaN  2019
# 1                 7:45                5:35         NaN  2019
# 2                 8:40                6:30         NaN  2019
# 3                 9:40                7:35         NaN  2019
# 4                10:40                8:25         NaN  2019
# ...                ...                 ...         ...   ...
# 4380             12:05                9:30      4380.0  2019
# 4381             16:15               13:30      4381.0  2019
# 4382             20:25               17:45      4382.0  2019
# 4383             21:55               19:25      4383.0  2019
# 4384             23:15               20:30      4384.0  2019
#
# [32843 rows x 14 columns]

# %%
set9 = set9.reset_index().drop(['index','Unnamed: 0'], axis = 1)

# %%
final_data1 = set9[[ 'Airline','Flight Number','Origin Airport','Destination Airport','Distance(Km)','Duration','DD','MM','YY','Scheduled Arrival', 'Scheduled Departure','Actual Arrival','Actual Departure']]

# %%
final_data1
# Out:
#       Airline  Flight Number Origin Airport Destination Airport  Distance(Km)  \
# 0          6E            171      New Delhi              Mumbai          1139
# 1          6E           5335      New Delhi              Mumbai          1139
# 2          6E            993      New Delhi              Mumbai          1139
# 3          6E            167      New Delhi              Mumbai          1139
# 4          6E            179         Mumbai                 Goa           412
# ...       ...            ...            ...                 ...           ...
# 32838      AI            506      New Delhi           Bangalore          1736
# 32839      AI            502      New Delhi           Bangalore          1736
# 32840      AI            174      New Delhi           Bangalore          1736
# 32841      AI            801      New Delhi           Bangalore          1736
# 32842      AI            504      New Delhi           Bangalore          1736
#
#       Duration  DD  MM    YY Scheduled Arrival Scheduled Departure  \
# 0        02:10   1  11  2019              7:05                4:55
# 1        01:48   1  11  2019              7:45                5:35
# 2        01:58   1  11  2019              8:40                6:30
# 3        01:46   1  11  2019              9:40                7:35
# 4        01:50   1  11  2019             10:40                8:25
# ...        ...  ..  ..   ...               ...                 ...
# 32838      NaN  31  12  2019             12:05                9:30
# 32839      NaN  31  12  2019             16:15               13:30
# 32840      NaN  31  12  2019             20:25               17:45
# 32841      NaN  31  12  2019             21:55               19:25
# 32842      NaN  31  12  2019             23:15               20:30
#
#       Actual Arrival Actual Departure
# 0               7:05             4:55
# 1               8:16             6:28
# 2               8:45             6:47
# 3               9:21             7:35
# 4              10:35             8:45
# ...              ...              ...
# 32838          11:53             9:27
# 32839          16:00            13:30
# 32840          20:39            17:54
# 32841          22:16            19:31
# 32842          23:33            20:51
#
# [32843 rows x 13 columns]

# %%
final_data1 = final_data1.drop(['Duration'], axis = 1)

# %%
final_data1
# Out:
#       Airline  Flight Number Origin Airport Destination Airport  Distance(Km)  \
# 0          6E            171      New Delhi              Mumbai          1139
# 1          6E           5335      New Delhi              Mumbai          1139
# 2          6E            993      New Delhi              Mumbai          1139
# 3          6E            167      New Delhi              Mumbai          1139
# 4          6E            179         Mumbai                 Goa           412
# ...       ...            ...            ...                 ...           ...
# 32838      AI            506      New Delhi           Bangalore          1736
# 32839      AI            502      New Delhi           Bangalore          1736
# 32840      AI            174      New Delhi           Bangalore          1736
# 32841      AI            801      New Delhi           Bangalore          1736
# 32842      AI            504      New Delhi           Bangalore          1736
#
#        DD  MM    YY Scheduled Arrival Scheduled Departure Actual Arrival  \
# 0       1  11  2019              7:05                4:55           7:05
# 1       1  11  2019              7:45                5:35           8:16
# 2       1  11  2019              8:40                6:30           8:45
# 3       1  11  2019              9:40                7:35           9:21
# 4       1  11  2019             10:40                8:25          10:35
# ...    ..  ..   ...               ...                 ...            ...
# 32838  31  12  2019             12:05                9:30          11:53
# 32839  31  12  2019             16:15               13:30          16:00
# 32840  31  12  2019             20:25               17:45          20:39
# 32841  31  12  2019             21:55               19:25          22:16
# 32842  31  12  2019             23:15               20:30          23:33
#
#       Actual Departure
# 0                 4:55
# 1                 6:28
# 2                 6:47
# 3                 7:35
# 4                 8:45
# ...                ...
# 32838             9:27
# 32839            13:30
# 32840            17:54
# 32841            19:31
# 32842            20:51
#
# [32843 rows x 12 columns]

# %%
final_data1.to_csv('final_sent.csv',index=False,encoding='utf-8')
